# %% [markdown]
# SESSION 3

# %% [markdown]
# Activity: Comment our code
#
# Information that might be helpful to comment are explanations on what the code might be doing, specific changes in the code the might make it unique to previous ones, any personal notes that might be helpful for yourself when looking back at the code, what the expected output might be.
#
# To write a good comment: be specific, clear, and concise. Try to make it easy for someone else to understand the code, walking them through it.

# %% [markdown]
# Activity: Your research
#
# FAIR: DOI apply to research papers published for our data. For my reaserch, I am not working on any datasets, I am moreso recruiting patients to gather data for a samller internal dataset. The small dataset from our patients are structured and readable by humans. We keep track of where the data came from, who colelcted it, and when for reusability.
#
# Context documents: My research would not require a context documents as I do not work with other datasets.

# %%
# Import/load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import PIL
import requests

# %%
# sample data
np.random.seed(613)
x = np.arange(50) #0-49
y1 = np.random.randint(0,100,50)
y2 = np.random.randint(0,100,50)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1)
ax.plot(x,y2)
# make line plot of both y1 and y2 on the same x axis

# %%
# making a legend
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = 'Person 1' )
ax.plot(x,y2, label = 'Person 2' )
ax.legend(loc='lower right')
fig.show()
# Out:
# C:\Users\liujo\AppData\Local\Temp\ipykernel_35780\923345210.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = 'Person 1')
ax.plot(x,y2, label = 'Person 2')
ax.legend(loc='lower right', 
          frameon = True, #add frame around the legend 
          fontsize = 12, #change font size 
          ncol = 2, #specify number of columns for the legend
          shadow = True ) #drop shadow
fig.show()
# Out:
# C:\Users\liujo\AppData\Local\Temp\ipykernel_35780\2291264571.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = 'Person 1')
ax.plot(x,y2, label = 'Person 2')

ax.legend(loc='upper left', 
          bbox_to_anchor =(1, 1)) #move it outside the plot; specify where we want it to go
fig.show()
# Out:
# C:\Users\liujo\AppData\Local\Temp\ipykernel_35780\3640060219.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = 'Person 1')
ax.scatter(x,y2, label = 'Person 2')
ax.legend(loc='lower right')

ax.text(10, 95, "This value is important!", # the text will start at the defined point
        ha='center', # alignment of text 
        color = 'red', # modify font colour 
        size = 20) # modify font size
        
fig.show()
# Out:
# C:\Users\liujo\AppData\Local\Temp\ipykernel_28808\157883534.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10]) # 0-10 for each axis

ax.text(1,5,". Data:(1,5)", transform=ax.transData)
ax.text(0.5, 0.1, ". Axes:(0.5, 0.1)", transform=ax.transAxes)
ax.text(0.2, 0.2, ". Figure:(0.2, 0.2)", transform=fig.transFigure )
# Out:
# Text(0.2, 0.2, '. Figure:(0.2, 0.2)')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

ax.annotate('This is important!', xy=(10, 95), xytext=(20, 94), # position of arrow and text
            arrowprops=dict(facecolor='black', 
                            shrink=0.05)) # gap between arrow and text
            # arrowprops = dict(arrowstyle = "wedge", color = " hotpink ") would give us a hot pink wedge instead of an arrow
fig.show()
16
# Out:
# C:\Users\liujo\AppData\Local\Temp\ipykernel_28808\3748085810.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# 16

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

ax.yaxis.set_major_locator(plt.NullLocator()) #remove ricks and labels
ax.xaxis.set_major_formatter(plt.NullFormatter()) #remove only labels

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.xaxis.set_major_locator(plt.MaxNLocator(3)) #set 3 max ticks

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) #set intervals for the ticks, 5

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
          
plt.xticks(rotation=45, ha='right') #horizontal alignment of ticks changed to the right of the numbers and tilted 45 degrees
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %%
#setting font dictionaires
font1 = {'family':'serif',
         'color':'indigo',
         'size':20} #numbers are not in the quotes

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

plt.xlabel('Shiney New X Axis!', fontdict=font1)
# Out:
# Text(0.5, 0, 'Shiney New X Axis!')

# %%
#styles, we have previosuly been changing out plots one element at a time; style can change multiple at a atime based on premade styles

#to view premade styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

# %%
plt.style.use('grayscale')
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

# %%
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
