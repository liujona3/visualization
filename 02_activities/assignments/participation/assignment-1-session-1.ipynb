# %%
#import os
#os.chdir("C:\\Users\\liujo\\Desktop\\DSI\\lecture material") #set directory

# %%
# Import/load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import PIL
import requests

# %%
#matplotlib

# figure = container
# axes = graphs
# artist = element to the axes (graphs; so colour, legends, axis titles and scales, text), not the figure (container)

# %%
#making a random scatterplot

np.random.seed(613) #sample data and setting a seed
x = np.arange(50) #x range to 50
y = np.random.randint(0, 100, 50) #0-100 with 50 values

fig, ax = plt.subplots(figsize=(5,3)) # set size to 5 by 3 inches, lxh
ax.scatter(x,y) #make it a scatterplot

# %%
fig, ax = plt.subplots(figsize=(5,3)) #fig (container), ax (assigning the graph to sit inside the container); i have a figure, inside the figure is an axes, the axes is ...
ax.bar(x,y) #change it to a barchart with same x and y values; can also make it a horizaontal barchart by changing it to: barh(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y) #make it into a lineplot

# %%
#activity 1
fig, ax = plt.subplots(figsize=(5,3))
ax.hist(y) #make it into a histrogram; only need y since you are just counting the frequency
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y) 

#defining 3 artists
ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
fig.tight_layout()

# %%
#setting font dictionaires
font1 = {'family':'sans-serif',
         'color':'blue',
         'size':20} #numbers are not in the quotes

font2 = {'family':'monospace',
         'color':'green',
         'size':14}

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y) 

#defining 3 artists
ax.set_title('Total growth over time', fontdict=font1)
ax.set_ylabel('Total growth', fontdict=font2)
ax.set_xlabel('Years since start', fontdict=font2)
fig.tight_layout()

# %%
#able to move labels and titles using loc

fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y) 

#defining 3 artists
ax.set_title('Total growth over time', fontdict=font1, loc = 'left')
ax.set_ylabel('Total growth', fontdict=font2)
ax.set_xlabel('Years since start', fontdict=font2)
fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(5, 3))

ax.scatter( x, y, 
           marker='*', #make it * 
           color = "indigo") # make it indigo

fig.show()
# Out:
# C:\Users\liujo\AppData\Local\Temp\ipykernel_30376\3818846625.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))

ax.plot( x, y, 
           marker='*',  
           color = "indigo",
           linestyle = '--',
           linewidth = 2)

fig.show()
# Out:
# C:\Users\liujo\AppData\Local\Temp\ipykernel_30376\648304117.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))

ax.plot( x, y, 
           marker='*',
           markersize = 12,  
           color = "#7425b9", #using hexcodes
           linestyle = '--',
           linewidth = 2,
           markeredgecolor = '#fa9359',
           markerfacecolor = '#000000')

ax.grid() #adds gridlines

# %%
fig, ax = plt.subplots(figsize=(5, 3))

ax.plot( x, y, 
           marker='*',
           markersize = 12,  
           color = "#7425b9", #using hexcodes instead
           linestyle = '--',
           linewidth = 2,
           markeredgecolor = '#fa9359',
           markerfacecolor = '#000000')

ax.grid(axis = 'y', color = "blue", 
        linewidth = 2, linestyle = '-.') #adds gridlines and customizes it

# %%
#Activity: exploring matlabplot
# libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
 
# Dataset:
a = pd.DataFrame({ 'group' : np.repeat('A',500), 'value': np.random.normal(10, 5, 500) })
b = pd.DataFrame({ 'group' : np.repeat('B',500), 'value': np.random.normal(13, 1.2, 500) })
c = pd.DataFrame({ 'group' : np.repeat('B',500), 'value': np.random.normal(18, 1.2, 500) })
d = pd.DataFrame({ 'group' : np.repeat('C',20), 'value': np.random.normal(25, 4, 20) })
e = pd.DataFrame({ 'group' : np.repeat('D',100), 'value': np.random.uniform(12, size=100) })
df = pd.concat([a,b,c,d,e])

# plot violin chart
sns.violinplot( x='group', y='value', data=df)

# add title
plt.title("Violin plot", loc="left")

# show the graph
plt.show()

# %% [markdown]
# I chose the violin plot because I find that it can provide valuable information.
#
# Aesthetic: It is somewhat pleasing to look at. There are not any unncessary effects/designs that make it too overwhelming. The addition of a colour helps with the visuals and it is quite clean in terms of not being overcrowded. While not needed, different colours for each group might emphasis the grouop differences, but the x axis already has them labeled.
#
# Sustantive: The violoin plot seems to accurately and honestly display the data since it is not using only one summary statistic. It incorporates the spread of the data allowing the viewer to see and skews in addition to the mean. It also clearly separates the groups so that the viewer can see the differences. The incremenets of the y axis are also accetable and easy to understand.
#
# Perceptual: Since the groups are distinctly separated from each other, we can understand the message that the visual is trying to portray, which is the differences seen between each group.
#
# Overall I would consider this visualization to be 'good'.
